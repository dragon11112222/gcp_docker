# %%
# GCP의 서비스 계정 리스트 확인
# !gcloud auth list
# Out:
#                   Credentialed Accounts
# ACTIVE  ACCOUNT
# *       714501709229-compute@developer.gserviceaccount.com
#
# To set the active account, run:
#     $ gcloud config set account `ACCOUNT`

# %%
# GCP의 프로젝트명 확인
# !gcloud config list project
# Out:
# [core]
# project = gcp-ai-406705
#
# Your active configuration is: [default]

# %%
# GCP에는 도커가 설치되어 있다.
# run을 할때 hello-world 이미지가 없다면 다운로드
# 도커 이미지를 다운로드 받고 실행
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# 이미지의 리스트를 확인
# !docker images
# Out:
# REPOSITORY            TAG       IMAGE ID       CREATED        SIZE
# park0122/helloflask   1.0       cf43b0c93b90   3 weeks ago    164MB
# hello-world           latest    9c7a54a9a43c   7 months ago   13.3kB

# %%
# 도커 이미지를 컨테이너로 생성하고 실행
# !docker run -it hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# process status + 모든 사용자의 프로세스(e) + 자세히(f) 
# !ps -ef
# Out:
# UID          PID    PPID  C STIME TTY          TIME CMD
# root           1       0  0 Dec06 ?        00:00:12 /sbin/init
# root           2       0  0 Dec06 ?        00:00:00 [kthreadd]
# root           3       2  0 Dec06 ?        00:00:00 [rcu_gp]
# root           4       2  0 Dec06 ?        00:00:00 [rcu_par_gp]
# root           6       2  0 Dec06 ?        00:00:00 [kworker/0:0H-kblockd]
# root           8       2  0 Dec06 ?        00:00:00 [mm_percpu_wq]
# root           9       2  0 Dec06 ?        00:00:00 [rcu_tasks_rude_]
# root          10       2  0 Dec06 ?        00:00:00 [rcu_tasks_trace]
# root          11       2  0 Dec06 ?        00:00:00 [ksoftirqd/0]
# root          12       2  0 Dec06 ?        00:00:03 [rcu_sched]
# root          13       2  0 Dec06 ?        00:00:00 [migration/0]
# root          15       2  0 Dec06 ?        00:00:00 [cpuhp/0]
# root          16       2  0 Dec06 ?        00:00:00 [cpuhp/1]
# ...

# %%
# 실행된(-a) 도커 이미지(컨테이너)의 목록을 확인
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED          STATUS                      PORTS     NAMES
# e8388232fdc3   hello-world   "/hello"   52 minutes ago   Exited (0) 52 minutes ago             suspicious_black
# 774bf0fe8039   hello-world   "/hello"   58 minutes ago   Exited (0) 58 minutes ago             optimistic_tereshkova
# c71c298ba3d0   hello-world   "/hello"   4 hours ago      Exited (0) 4 hours ago                hopeful_grothendieck
# 6854d6a8c271   hello-world   "/hello"   4 hours ago      Exited (0) 4 hours ago                competent_dijkstra
# 3b2f57182cb0   hello-world   "/hello"   4 hours ago      Exited (0) 4 hours ago                elegant_cori

# %%
# docker hub에서 이미지를 다운로드
# !docker image pull ubuntu:latest
# Out:
# latest: Pulling from library/ubuntu
#
# Digest: sha256:8eab65df33a6de2844c9aefd19efe8ddb87b7df5e9185a4ab73af936225685bb[1A
# Status: Downloaded newer image for ubuntu:latest
# docker.io/library/ubuntu:latest

# %%
# 가지고 있는 도커 이미지 목록을 확인
# !docker image ls -a
# Out:
# REPOSITORY            TAG       IMAGE ID       CREATED        SIZE
# ubuntu                latest    b6548eacb063   5 days ago     77.8MB
# park0122/helloflask   1.0       cf43b0c93b90   3 weeks ago    164MB
# hello-world           latest    9c7a54a9a43c   7 months ago   13.3kB

# %%
# 현재 도커 이미지를 사용해서 컨테이너를 생성한 것이 없어야 한다.
# 도커 이미지를 삭제 (IMAGE ID)를 입력해서 삭제
# !docker image rm cf43b0c93b90
# Out:
# Untagged: park0122/helloflask:1.0
# Untagged: park0122/helloflask@sha256:c75f5d3cc3324d01988fe033e282ee388d8fcbaed462ecbcf636545754d5e2c1
# Deleted: sha256:cf43b0c93b907a3f90eb8bee2d89470b4ba9225a74e32162a25c6294d1c2ef37
# Deleted: sha256:7eec5489f9f11151d09f83fc13d198d171f871a0efc6d4d3ec4bb25bacbafaa7
# Deleted: sha256:d8e695d6fb64dc07183c8885d9302aba995260a964e536f05f6533dfbba0f581
# Deleted: sha256:eb0c118c42f7efe06d1e9ba54d87a2a21b11b646db0931a31e0118f356da45ca
# Deleted: sha256:45740cd30a0ca0e475f5f452f2ddeb9d8b12e7592fa1071d39342ef82138a330
# Deleted: sha256:114045a1e89b7e80214d36b9fd9c2d6e21cc5db950b7edd48519059ff4ca4b7e
# Deleted: sha256:11f7d22b461c1952becb65f77881db1541118e36e7e966aeb97d6bfb579fce2a
# Deleted: sha256:1d7fd67e2e22576ef2f988225daaf0fb7aa988db5b033efa5d48853518f89fcb
# Deleted: sha256:70e628269d9fa63e3ddaa5e293bbc8aba5079d63f473f75c310b0c3cf2496f8e

# %% [markdown]
# ### 스냅샷 : 컨테이너 안의 리눅스 디렉토리와 파일들을 특정 타이밍에 저장한 파일

# %%
from PIL import Image
from IPython.display import display

img = Image.open('/home/jupyter/IMG_5017.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x339>

# %%
# 도커를 실행 
# i옵션 : 컨테이너의 표준 출력(stdout)을 연다.
# t옵션 : tty(단말 디바이스) -> 텍스트 기반으로 입출력

# 컨테이너 이미지를 실행, "test01"이라는 이름으로 ubuntu이미지를 실행해서 ls명령어를 실행
# !docker container run -it --name "test01" ubuntu /bin/ls
# Out:
# bin   dev  home  lib32	libx32	mnt  proc  run	 srv  tmp  var
# boot  etc  lib	 lib64	media	opt  root  sbin  sys  usr

# %%
# 컨테이너의 리스트를 확인
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED       STATUS                   PORTS     NAMES
# c71c298ba3d0   hello-world   "/hello"   7 hours ago   Exited (0) 7 hours ago             hopeful_grothendieck
# 6854d6a8c271   hello-world   "/hello"   7 hours ago   Exited (0) 7 hours ago             competent_dijkstra
# 3b2f57182cb0   hello-world   "/hello"   7 hours ago   Exited (0) 7 hours ago             elegant_cori

# %%
# 사용하지 않는 컨테이너 삭제
# !docker container rm c71c298ba3d0 6854d6a8c271 3b2f57182cb0
# Out:
# c71c298ba3d0
# 6854d6a8c271
# 3b2f57182cb0

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE     COMMAND   CREATED   STATUS    PORTS     NAMES

# %%
# 컨테이너가 삭제되면 docker이미지도 삭제 가능
# !docker image rm hello-world
# Out:
# Untagged: hello-world:latest
# Untagged: hello-world@sha256:c79d06dfdfd3d3eb04cafd0dc2bacab0992ebc243e083cabe208bac4dd7759e0
# Deleted: sha256:9c7a54a9a43cca047013b82af109fe963fde787f63f9e016fdc3384500c2823d
# Deleted: sha256:01bb4fce3eb1b56b05adf99504dafd31907a5aadac736e36b27595c8b92f07f1

# %%
# 만약 container의 bash환경에서 창이 닫혔을 경우
# 재진입을 해야하는데 사용하는 명령
# 가동 컨테이너 연결
#                         [컨테이너ID]
#!docker container attach d8069c1bab72

# %%
#                         [컨테이너ID]  [도커 이미지명:태그]
#!docker container commit d8069c1bab72 park0122/mytest:1.0

# %%
# docker hub에 로그인
# 성공할 경우 Login Succeeded
# !docker login --username park0122@gmail.com --password *********
# Out:
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/jupyter/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# 도커 이미지를 push한다.
# !docker image push park0122/mytest:1.0
# Out:
# The push refers to repository [docker.io/park0122/mytest]
#
# b6bb6eaf: Preparing
# b6bb6eaf: Pushed   211.2MB/204.8MBntu 1.0: digest: sha256:212343083d82282bd2d3c5a439e3aebcf0bada34f7c181cab8a2ecf40775d750 size: 741

# %%
# docker hub 로그아웃
# !docker logout
# Out:
# Removing login credentials for https://index.docker.io/v1/
